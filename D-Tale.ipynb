# %% [markdown]
# # D-Tale

# %% [markdown]
# ## Installing Packages

# %%
pip install dtale
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## EDA Processing

# %%
import dtale
import pandas as pd

dtale.show(pd.read_csv("C:\\Users\\MAJAHAR\\Ineuron\\EDA\\Dataset\\data1\\Travel.csv"))
# Out:
# C:\Users\MAJAHAR\anaconda3\lib\site-packages\dtale\views.py:746: FutureWarning:
#
# ['TypeofContact'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-5G00HUD:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Results

# %% [markdown]
# ![Screenshot%20%2823%29.png](attachment:Screenshot%20%2823%29.png)

# %% [markdown]
# ![Screenshot%20%2824%29.png](attachment:Screenshot%20%2824%29.png)

# %% [markdown]
# ![correlations.png](attachment:correlations.png)
